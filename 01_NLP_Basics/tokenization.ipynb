# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsivirigineni/AI-Resume-Analyzer/blob/main/01_NLP_Basics/tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
#sample text
txt = "NLTK provide powerfull tools for tokenization. It includes word tokenization and sentance tokenization"

# %%
txt
# Out:
# 'NLTK provide powerfull tools for tokenization. It includes word tokenization and sentance tokenization'

# %%
type(txt)
# Out:
# str

# %%
#word tokenization
word_tokenize(txt)
# Out:
# ['NLTK',
#  'provide',
#  'powerfull',
#  'tools',
#  'for',
#  'tokenization',
#  '.',
#  'It',
#  'includes',
#  'word',
#  'tokenization',
#  'and',
#  'sentance',
#  'tokenization']

# %%
txt2 = 'Boy is good Girl is good and both Boy and Girl is good'

# %%
word_tokenize(txt2)
# Out:
# ['Boy',
#  'is',
#  'good',
#  'Girl',
#  'is',
#  'good',
#  'and',
#  'both',
#  'Boy',
#  'and',
#  'Girl',
#  'is',
#  'good']

# %%
sent_tokenize(txt)
# Out:
# ['NLTK provide powerfull tools for tokenization.',
#  'It includes word tokenization and sentance tokenization']
